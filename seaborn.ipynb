# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv(r"D:\WORK\university\Diabetic-prediction-using-multiple-machine-learning-algorithms\diabetes_prediction_dataset.csv")

# %%
data.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
data.isnull()
# Out:
#        gender    age  hypertension  heart_disease  smoking_history    bmi  \
# 0       False  False         False          False            False  False
# 1       False  False         False          False            False  False
# 2       False  False         False          False            False  False
# 3       False  False         False          False            False  False
# 4       False  False         False          False            False  False
# ...       ...    ...           ...            ...              ...    ...
# 99995   False  False         False          False            False  False
# 99996   False  False         False          False            False  False
# 99997   False  False         False          False            False  False
# 99998   False  False         False          False            False  False
# 99999   False  False         False          False            False  False
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
sns.heatmap(data.isnull(),cbar=True, cmap='viridis')
# Out:
# <Axes: >

# %%
data['gender']= LabelEncoder().fit_transform(data['gender']) 
data['smoking_history']= LabelEncoder().fit_transform(data['smoking_history'])

# %%
data_1 = data.head()

# %%
plot.figure(figsize=(5,5))
plot.title('age distribution')
plot.grid(True)
sns.histplot(data = data, x = 'age', bins= 10, color='red')
# Out:
# <Axes: title={'center': 'age distribution'}, xlabel='age', ylabel='Count'>

# %%
# Define the color palette
colors = {0: 'blue', 1: 'red', 2: 'green'}

# Create the count plot
sns.countplot(x='gender', data=data,  palette=colors)

# Display the plot


#colors = {'Male': 'blue', 'Female': 'red', 'Other': 'green'}
#plot.figure(figsize=(6, 4))
#sns.countplot(x='gender', data=data, palette=colors)
#plot.title('Count Plot of Gender')
#plot.xlabel('Gender')
#plot.ylabel('Count')
#plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 8
#       5 sns.countplot(x='gender', data=data,  palette=colors)
#       7 # Display the plot
# ----> 8 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.countplot(x='gender', data=data,)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.set_style('darkgrid')
plot.figure(figsize=(5,5))
plot.grid(True)
sns.lineplot(data=data_1, x='age', y='blood_glucose_level', hue= 'gender', palette= 'plasma')
# Out:
# <Axes: xlabel='age', ylabel='blood_glucose_level'>

# %%
avg_smoking_history = data.groupby('smoking_history')
sns.barplot(data=data, x= 'smoking_history',y= 'blood_glucose_level', palette='plasma')
plot.title('Average Blood Glucose Level by Smoking History')
plot.grid(True)
sns.set_style('darkgrid')

# %%
avg_smoking_history = data.groupby("smoking_history")
sns.boxplot(data=data,x= 'smoking_history', y= 'blood_glucose_level', hue= 'diabetes', saturation=100, palette= 'plasma',)
plot.figure(figsize=(5,50))
sns.set_style('ticks')

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0             0              1                4  25.19
# 1       0  54.0             0              0                0  27.32
# 2       1  28.0             0              0                4  27.32
# 3       0  36.0             0              0                1  23.45
# 4       1  76.0             1              1                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
sns.violinplot(data=data, x= 'gender', y= 'age', kde= 'True')
plot.grid('True')

# %%
data_1 = data.head()

# %%
data_1
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0             0              1                4  25.19
# 1       0  54.0             0              0                0  27.32
# 2       1  28.0             0              0                4  27.32
# 3       0  36.0             0              0                1  23.45
# 4       1  76.0             1              1                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
sns.stripplot(data=data_1, x='hypertension', y= 'HbA1c_level', hue= 'heart_disease', dodge='True' )
# Out:
# <Axes: xlabel='hypertension', ylabel='HbA1c_level'>

# %%
sns.jointplot(data=data_1, x='hypertension', y= 'HbA1c_level', kind= 'kde')
